# %% [markdown]
# Defining Python Class
# >>Using the Class keyword to create a class in Python
# Syntax:
#
# class ClassName:

# %%
#creating a class with properties
class Person:
  name = "Juan Dela Cruz"
  age =27

# %% [markdown]
# Python Objects
# Syntax : objectName = ClassName()

# %%
#Creating an Object of a class
person1 = Person()

# %% [markdown]
# Accessing Class Attributes Using Objects

# %%
#Modify the name property
person1.name = "Jose Rizal"

#Accessing the age property
person1.age

# %%
#Complete Example
#Define a class
class Person:
  name = "Juan Dela Cruz"
  age =27

#Creating an object of a class
  person1 = Person()

#Accessing attributes and assign new values
person1.name = "Jose Rizal"
person1.age =20

print(f"Name: {person1.name}, Age: {person1.age} ")

# %% [markdown]
# Creating Multiple Objects of Python Class

# %%
#Define a class
class Employee:
  #defining a property
  employeeID = 0

#Create two objects of the Employee class
employee1 = Employee()
employee2 = Employee()

#Access a property using employee1
employee1.employeeID = 1001
print(f"Employee ID:  {employee1.employeeID}")

#Access property using employee2
employee2.employeeID = 1002
print(f"Employee ID:  {employee2.employeeID}")

# %% [markdown]
# Python Methods
# A Python function can be defined inside a class, and this is called a method

# %%
# create a class
class Room:
    length = 0.0
    breadth = 0.0

    # method to calculate area
    def calculate_area(self):
        print("Area of Room =", self.length * self.breadth)

# create object of Room class
study_room = Room()

# assign values to all the properties
study_room.length = 42.5
study_room.breadth = 30.8

# access method inside class
study_room.calculate_area()

# %% [markdown]
# Python Constructors
# Previous Example:
#
# class Person:
#   name=""
#
# Create object
# person1 = Person()
#
# To initialize using contructors
# def __init__(self, name=""):
#   self.name = name
#
# person1 = Person("Mary Santos")

# %%
class Person:
  def __init__(self, name=""):
    self.name = name

person1 = Person("Mary Santos")

print(f"Name: {person1.name}")
